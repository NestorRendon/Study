# %%
s='string'

# %%
s[1:3]
# Out:
# 'tr'

# %%
for i in range(len(s)-1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
s[::-1]
# Out:
# 'gnirts'

# %%
s[::]
# Out:
# 'gr'

# %%
for j in range (1,14,8):
    print(j)
# Out:
# 1
# 9

# %%
[""] * 6
# Out:
# ['', '', '', '', '', '']
